# %%
import pandas as pd
import pickle
filename = open('./data/total.pickle','rb')
df = pickle.load(filename)

# %%
df
# Out:
#                                   company    country  \
# 10                                UMeKang  Singapore
# 3                     Cresco Data Pte Ltd  Singapore
# 8       iKas International (Asia) Pte Ltd  Singapore
# 6                            Vault Dragon  Singapore
# 5                           TSA Solutions  Singapore
# 4                              EkkBaz.com  Singapore
# 10                       6Estates Pte Ltd  Singapore
# 5                              Transforma  Singapore
# 10                Shentilium Technologies  Singapore
# 10                          TSA Solutions  Singapore
# 4                       BGC Group Pte Ltd  Singapore
# 4                       Beacon Consulting  Singapore
# 9                    Raintree Partnership  Singapore
# 6                       Beacon Consulting  Singapore
# 9                               Collabera  Singapore
# 7                           TSA Solutions  Singapore
# 4        Prime Solutions Provider Pte Ltd  Singapore
# ...
